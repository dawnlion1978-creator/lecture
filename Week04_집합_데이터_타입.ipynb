# %%
# Exercise1 >> fruits 리스트 데이터 만들기
fruits = [ '사과', '복숭아', '포도']

# fruits 확인하기
print(fruits)
# Out:
# ['사과', '복숭아', '포도']

# %%
# Exercise2 >>  fruits 리스트에서 '복숭아'만 출력
fruits[1]
# Out:
# '복숭아'

# %%
# Exercise3 >>  fruits 리스트에서 '사과'를 '토마토'로 변경하기
fruits[0] = '토마토'
fruits
# Out:
# ['토마토', '복숭아', '포도']

# %%
# Exercise4 >> fruits 리스트에서 여러개의 요소 조회하기
fruits = ['토마토', '복숭아', '포도','키위']
print(fruits)

# fruits 리스트에서  “복숭아, 포토” 조회하기
fruits[1:3]
# Out:
# ['토마토', '복숭아', '포토', '키위']
# ['복숭아', '포토']

# %%
#fruits 리스트에서  “토마토, 복숭아, 포도” 조회하기
fruits[:3]
# Out:
# ['토마토', '복숭아', '포토']

# %%
#fruits 리스트에서  “복숭아, 포도,키위” 조회하기
fruits[1 : ]
# Out:
# ['복숭아', '포토', '키위']

# %%
#fruits 리스트에서  “토마토, 복숭아, 포도,키위” 조회하기
fruits[:]
# Out:
# ['토마토', '복숭아', '포토', '키위']

# %%
# Exercise5 >> ages 딕셔너리 만들기

ages = { '박찬호' : 48 , '박지성': 40, '박세리': 50}
ages
# Out:
# {'박찬호': 48, '박지성': 40, '박세리': 50}

# %%
# Exercise6 >> ages 딕셔너리에서'박지성'의 나이를 출력하기

ages['박지성']
# Out:
# 40

# %%
# Exercise7 >> 손홍민의 나이  38을 추가
ages['손홍민'] = 38
print(ages)
# Out:
# {'박찬호': 48, '박지성': 40, '박세리': 50, '손홍민': 38}

# %%
# Exercise8 >> 박지성의 나이 40을 45로 수정하기
ages['박지성'] = 45
print(ages)
# Out:
# {'박찬호': 48, '박지성': 45, '박세리': 50, '손홍민': 38}

# %%
# Exercise9 >> ‘악뮤, 던, 한로로’롤 요소로 가지는 singer 리스트 생성

singer = ['악뮤', '던', '한로로']
print(singer)
# Out:
# ['악뮤', '던', '한로로']

# %%
# Exercise10 >> singer 리스트에서 ‘한로로’만 출력하기

singer[2]
# Out:
# '한로로'

# %%
# Exercise11 >>  singer 리스트에서 ‘던,한로로’ 출력하기
singer[1:]
# Out:
# ['던', '한로로']

# %%
# Exercise12 >> 아래 처럼 구성된 dict 딕셔너리 생성
dict = { 'A': "Apple", "B":"Banna", "C": "Coffee"}
print(dict)
# Out:
# {'A': 'Apple', 'B': 'Banna', 'C': 'Coffee'}

# %%
# Exercise13 >> dict 딕셔너리에  { ‘D’ : ‘Data’}요소 추가하기
dict["D"] = "Data"
print(dict)
# Out:
# {'A': 'Apple', 'B': 'Banna', 'C': 'Coffee', 'D': 'Data'}

# %%
# Exercise14 >> dict 딕셔너리에  { ‘A’ : ‘Album’}으로 변경하기
dict["A"] = "Album"
print(dict)
# Out:
# {'A': 'Album', 'B': 'Banna', 'C': 'Coffee', 'D': 'Data'}
